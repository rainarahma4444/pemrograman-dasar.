# %% [markdown]
# <a href="https://colab.research.google.com/github/rainarahma4444/pemrograman-dasar./blob/main/Untitled0_ipynb_ESSAY_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
NAMA : RAINA RAHMA
NIM : 4232501013
RPE 3A PAGI

A. SOAL ESSAI
1. Python mengenal beberapa jenis ekspresi (aritmatika, relasional, logika, assignment). Carilah referensi (dokumentasi resmi Python atau sumber lain) yang menjelaskan urutan prioritas operator (operator precedence) di Python, lalu jelaskan dengan kata-katamu sendiri: mengapa ekspresi 10 + 5 * 2 menghasilkan 20, bukan 30? Sertakan sumber yang kamu gunakan.
Bedasarkan referensi sumber python documentation pada bagian 6.expression 6.17.operator precedence terdapat aturan menentukan operator mana yang dioperasikan terlebih dahulu dimana python memiliki urutan prioritas operator dari yang paling tinggi hingga yang paling rendah. Didalam operasi 10 + 5 * 2 perkalian (*) memiliki prioritas lebih tinggi daripada penjumlahan (+).
Sehingga pada operasi tersebut yang lebih dulu di proses adalah 5*2 lalu + 10, sehingga hasilnya adalah 20.

2.Jelaskan perbedaan mendasar antara operator relasional (>, <, ==, dll.) dan operator logika (and, or, not) dalam Python. Berikan satu contoh situasi nyata (boleh di luar konteks pembangkit) di mana kedua jenis operator ini harus dipakai bersamaan dalam satu ekspresi untuk menghasilkan keputusan yang benar.
Operator relasional digunakan untuk membandingkan dua nilai atau kondisi, hasil perbandingannya adalah true atau false contohnya >, <, ==, >=, <=, dan !=.
sedangkan Operator logika digunakan untuk menggabungkan atau memproses yang sudah menghasilkan true atau false, yang digunakan pada operator logika adalah and, or, dan not.
Contoh nyata pada pembangkit :
suhu_generator = 75
tekanan_oli = 4.5

suhu_generator < 90     75 < 90 → True
tekanan_oli > 3         4.5 > 3 → True
ini merupakan operator rasional.

Suhu aman          → True
Tekanan oli aman   → True
true and true → True
maka generator dapat beroperasi
ini merupakan operator logika

3.Cari satu contoh kasus nyata (artikel, forum programmer, atau dokumentasi) tentang bug atau kesalahan perhitungan yang terjadi akibat salah memahami operator precedence
 (misalnya lupa memberi tanda kurung). Ringkas kasus tersebut dalam 3–5 kalimat, lalu jelaskan bagaimana seharusnya kode itu diperbaiki.

Pada Python Bug Tracker Issue 28550, seorang programmer mengalami error karena salah memahami urutan prioritas operator pada ekspresi if-else. Programmer mengira seluruh obj.a, obj.b akan diproses sebagai satu bagian, tetapi Python sebenarnya hanya menerapkan kondisi if-else pada bagian obj.b.
 Akibatnya, ketika obj bernilai None, program tetap mencoba mengakses obj.a dan menghasilkan error. Perbaikannya adalah menambahkan tanda kurung menjadi a, b = (obj.a, obj.b) if obj else [None, None] agar urutan operasi sesuai dengan yang dimaksud.
# Out:
#   File "/tmp/ipykernel_4255/3650199433.py", line 3
#     RPE 3A PAGI
#         ^
# SyntaxError: invalid decimal literal
